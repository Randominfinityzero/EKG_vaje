# %%
import numpy as np
import matplotlib.pyplot as plt
import random

# %%
t=np.linspace(0, 100, num=1000, endpoint=True)
y1=0.1*np.sin(2*np.pi/400.0*t)
ft=np.array([0.02*(2.0*random.random()-1) for i in range(len(y1))])
#print(f)
y2=0.1*np.sin(2*np.pi/10.0*t)+ft
y2[y2<0]*=abs(0.2*np.sin(2*np.pi/40.0*t[y2<0]))
plt.figure(figsize=(16,6))
plt.plot(t,y1+y2)
plt.show()

# %% [markdown]
# <h1>Glajenje</h1>

# %% [markdown]
# <h1>Iskanje lokalnih ekstremov</h1>

# %% [markdown]
# <h1>Lasnosti obdelanega signala</h1>
